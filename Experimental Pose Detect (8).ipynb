# %%
import torch
from torchvision import transforms

from utils.datasets import letterbox
from utils.general import non_max_suppression_kpt
from utils.plots import output_to_keypoint, plot_skeleton_kpts

import matplotlib.pyplot as plt
import cv2
import numpy as np
import statistics

import math

fc = 1
#na = np.empty((1, 51))
na = []
actualKp = []
currentKeypoints = []
c=0
lK = []
nK = []
la = []

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def load_model():
    model = torch.load('yolov7-w6-pose.pt', map_location=device)['model']
    # Put in inference mode
    model.float().eval()

    if torch.cuda.is_available():
        # half() turns predictions into float16 tensors
        # which significantly lowers inference time
        model.half().to(device)
    return model

model = load_model()

# %%
def run_inference(image):
    # Resize and pad image
    image = letterbox(image, 960, stride=64, auto=True)[0] # shape: (567, 960, 3)
    # Apply transforms
    image = transforms.ToTensor()(image) # torch.Size([3, 567, 960])
    if torch.cuda.is_available():
        image = image.half().to(device)
    # Turn image into batch
    image = image.unsqueeze(0) # torch.Size([1, 3, 567, 960])
    with torch.no_grad():
        output, _ = model(image)
    return output, image

# %%
def draw_keypoints(output, image):
    global fc, c, t, nK, lK, na, nc
    output = non_max_suppression_kpt(output, 
                                     0.04, # Confidence Threshold
                                     0.25, # IoU Threshold
                                     nc=model.yaml['nc'], # Number of Classes
                                     nkpt=model.yaml['nkpt'], # Number of Keypoints
                                     kpt_label=True)
    #0.4, 0.25
    with torch.no_grad():
        output = output_to_keypoint(output)
        #print(f'Frame Number: {fc}; Data Size: {output.shape}')
    try:
        t = output[0] #retrieves only first skeleton data
        t = t[-51:] #retrieves last 51 elements
        #t = t[::3] cuts every third element (confidence level)
        t = [x for i, x in enumerate(t) if (i+1)%3 != 0]
        #append all nose x coords
        nK.append(t[10])
        #appends all hip x coords
        lK.append(t[22]) #array t is unsorted, the x values is every other starting at index 0 and y values every other starting at 1
        #index 22 gives the x coordinate for right hip joint
        na.append(t)
        currentKeypoints = []
    except:
        #currentKeypoints = 
        c += 1
    nimg = image[0].permute(1, 2, 0) * 255
    nimg = nimg.cpu().numpy().astype(np.uint8)
    nimg = cv2.cvtColor(nimg, cv2.COLOR_RGB2BGR)

    
    
    for idx in range(output.shape[0]):
        plot_skeleton_kpts(nimg, output[idx, 7:].T, 3)
    
    
        
    return nimg

# %%
video = "C:/Users/jonso/OneDrive/Desktop/Testing Data 2.mp4"
#video = "C:/Users/jonso/OneDrive/Desktop/Free Training Data.mp4"
path = 'test.npy'
#swimPose_estimate(video, path)

# %%
nc = 0
fa = []
def swimPose_estimate(filename, savepath):
    global fc, c, t, nK, lK, na, fa
    
    cap = cv2.VideoCapture(filename)
    totalFrames = math.floor(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))/32)
    print(f'TF: {totalFrames}')
    i = 0
    fa = []
    
    while i < totalFrames:
        na = []
        fc = 0
        nK = []
        lK = []
        c=0
        poseH(filename, "none", i*32)
        print(f'Original data: {c} empty frames')
        #print("nK: ",nK)
        #print("lK: ",lK)

        #print("-=-=-=-=-=-=-=-")
        #print("nK mode: ",statistics.median(nK))
        #print("lK mode: ",statistics.median(lK))
        #print(c)
        cap.release()
        cv2.destroyAllWindows()
        
        if c > 5:
            fc = 0
            c=0
            if statistics.median(nK) > statistics.median(lK):
                na = []
                #print("needs counterclockwise rotation")
                poseH(filename, "cc", i*32)
                print("transformation completed")
                print(f'Counterclockwise rotation; {c} empty frames')
                if c <= 5:
                    fa.extend(na)
                else:
                    print("too many missing frames, batch discarded")
            else:
                na = []
                #print("needs clockwise rotation")
                poseH(filename, "c", i*32)
                print("transformation completed")
                print(f'Clockwise rotation; {c} empty frames')
                if c <= 5:
                    fa.extend(na)
                else:
                    print("too many missing frames, batch discarded")
        else:
            print("no change necessary")
            fa.extend(na)

        
        #print(na[10])
        #skelData = np.array(na)
        #skelData = skelData.reshape(skelData.shape[0], 17, 2)
        #print(skelData[10])
    
        i += 1
        print(f'batch {i} complete')
        
    print("=======================================================")
    print("-----------Skeleton Data Extraction Complete-----------")
    print("=======================================================")

    x = np.array(fa)
    x = np.reshape(x, (x.shape[0], 17, 2))
    print(f'Array shape: {x.shape}')
    np.save(savepath, x)
    print(f'Data saved to: {savepath}')
    
    print("=======================================================")
    cv2.destroyAllWindows()

# %%
def swimPose_train(filename, savepath, labelpath):
    global fc, c, t, nK, lK, na, fa, la
    
    cap = cv2.VideoCapture(filename)
    totalFrames = math.floor(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))/32)
    print(f'TF: {totalFrames}')
    i = 0
    fa = []
    la = []
    
    while i < totalFrames:
        na = []
        fc = 0
        nK = []
        lK = []
        c=0
        poseH(filename, "none", i*32)
        print(f'Original data: {c} empty frames')
        #print("nK: ",nK)
        #print("lK: ",lK)

        #print("-=-=-=-=-=-=-=-")
        #print("nK mode: ",statistics.median(nK))
        #print("lK mode: ",statistics.median(lK))
        #print(c)
        cap.release()
        #cv2.destroyAllWindows() #remove
        
        if c > 5:
            cv2.destroyAllWindows()
            fc = 0
            c=0
            if statistics.median(nK) > statistics.median(lK):
                na = []
                #print("needs counterclockwise rotation")
                poseH(filename, "cc", i*32)
                print("transformation completed")
                print(f'Counterclockwise rotation; {c} empty frames')
                if c <= 5:
                    fa.extend(na)
                else:
                    print("too many missing frames, batch discarded")
            else:
                na = []
                #print("needs clockwise rotation")
                poseH(filename, "c", i*32)
                print("transformation completed")
                print(f'Clockwise rotation; {c} empty frames')
                if c <= 5:
                    fa.extend(na)
                else:
                    print("too many missing frames, batch discarded")
        else:
            print("no change necessary")
            fa.extend(na)

        #print(na[10])
        #skelData = np.array(na)
        #skelData = skelData.reshape(skelData.shape[0], 17, 2)
        #print(skelData[10])
    
        i += 1
        print(f'batch {i} complete')
        if c<=10:
            while True:
                key = cv2.waitKey(0)

                if key == ord('0'):
                    print("Batch labeled as Freestyle")
                    [la.append([0]) for _ in range(32)]
                    break
                elif key == ord('1'):
                    print("Batch labeled as Butterfly")
                    [la.append([1]) for _ in range(32)]
                    break
                elif key == ord('2'):
                    print("Batch labeled as Backstroke")
                    [la.append([2]) for _ in range(32)]
                    break
                elif key == ord('3'):
                    print("Batch labeled as Breastroke")
                    [la.append([3]) for _ in range(32)]
                    break
                elif key == ord('4'):
                    print("Batch labeled as Underwater")
                    [la.append([4]) for _ in range(32)]
                    break
                elif key == ord('5'):
                    print("Batch labeled as Dive")
                    [la.append([5]) for _ in range(32)]
                    break
                """
                elif key == ord('d'):
                    print("Batch Manually Discarded")
                """
            cv2.destroyAllWindows()
        
    print("=======================================================")
    print("-----------Skeleton Data Extraction Complete-----------")
    print("=======================================================")

    x = np.array(fa)
    x = np.reshape(x, (x.shape[0], 17, 2))
    a = np.array(la)
    while a.shape[0] != x.shape[0]:
        a = np.delete(a, -1, axis=0)
    print(f'Array shape: {x.shape}')
    print(f'Label shape: {a.shape}')
    np.save(savepath, x)
    np.save(labelpath, a)
    print(f'Skeleton Data saved to: {savepath}')
    print(f'Label Data saved to: {labelpath}')
    
    print("=======================================================")
    #cv2.destroyAllWindows()

# %%
def poseH(filename, rotation, currentFrame):
    global fc, c, t, nK, lK, na
    #cv2.destroyAllWindows()

    cap = cv2.VideoCapture(filename)
    # VideoWriter for saving the video
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')
    out = cv2.VideoWriter('Free_Skel.mp4', fourcc, 30.0, (int(cap.get(3)), int(cap.get(4))))
    
    cap.set(cv2.CAP_PROP_POS_FRAMES, currentFrame)

    
    while fc < 32 and cap.isOpened():
        (ret, frame) = cap.read()
        if ret == True:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            if rotation == "cc":
                frame = cv2.rotate(frame, cv2.ROTATE_90_COUNTERCLOCKWISE)
            elif rotation == "c":
                frame = cv2.rotate(frame, cv2.ROTATE_90_CLOCKWISE)
            elif rotation == "none":
                pass

            output, frame = run_inference(frame)
            frame = draw_keypoints(output, frame)
            fc += 1
            
            frame = cv2.resize(frame, (int(cap.get(3)), int(cap.get(4))))
            
            if rotation == "cc" or rotation == "c":
                frame = cv2.resize(frame,(720,1280),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
            else:
                frame = cv2.resize(frame,(1280,720),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
            out.write(frame)
            cv2.imshow('Pose estimation', frame)
        else:
            break

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    out.release()
    #cv2.destroyAllWindows()

# %%
# %%time
video = "C:/Users/jonso/OneDrive/Desktop/Testing Data 2.mp4"
path = 'skel2_test.npy'
labelPath = 'label2_test.npy'
#swimPose_train(video, path, labelPath)
#swimPose_estimate(video, path)
#counterclockwise
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time
video = "C:/Users/jonso/OneDrive/Desktop/Free Training Data.mp4"
path = 'Free_Skel_Training.npy'
swimPose_estimate(video, path)
#counterclockwise
# Out:
# TF: 285
# C:\Users\jonso\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 2 empty frames
# batch 1 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 2 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 3 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 4 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 5 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 6 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 7 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 8 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 9 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 10 complete
# Original data: 21 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 11 complete
# Original data: 20 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 12 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 13 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 14 complete
# Original data: 3 empty frames
# no change necessary
# batch 15 complete
# Original data: 0 empty frames
# no change necessary
# batch 16 complete
# Original data: 2 empty frames
# no change necessary
# batch 17 complete
# Original data: 0 empty frames
# no change necessary
# batch 18 complete
# Original data: 0 empty frames
# no change necessary
# batch 19 complete
# Original data: 0 empty frames
# no change necessary
# batch 20 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 21 complete
# Original data: 19 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 22 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 23 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 24 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 25 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 26 complete
# Original data: 5 empty frames
# no change necessary
# batch 27 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 28 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 29 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 30 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 31 complete
# Original data: 3 empty frames
# no change necessary
# batch 32 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 33 complete
# Original data: 3 empty frames
# no change necessary
# batch 34 complete
# Original data: 1 empty frames
# no change necessary
# batch 35 complete
# Original data: 0 empty frames
# no change necessary
# batch 36 complete
# Original data: 0 empty frames
# no change necessary
# batch 37 complete
# Original data: 0 empty frames
# no change necessary
# batch 38 complete
# Original data: 0 empty frames
# no change necessary
# batch 39 complete
# Original data: 0 empty frames
# no change necessary
# batch 40 complete
# Original data: 0 empty frames
# no change necessary
# batch 41 complete
# Original data: 0 empty frames
# no change necessary
# batch 42 complete
# Original data: 0 empty frames
# no change necessary
# batch 43 complete
# Original data: 0 empty frames
# no change necessary
# batch 44 complete
# Original data: 0 empty frames
# no change necessary
# batch 45 complete
# Original data: 0 empty frames
# no change necessary
# batch 46 complete
# Original data: 0 empty frames
# no change necessary
# batch 47 complete
# Original data: 0 empty frames
# no change necessary
# batch 48 complete
# Original data: 0 empty frames
# no change necessary
# batch 49 complete
# Original data: 0 empty frames
# no change necessary
# batch 50 complete
# Original data: 0 empty frames
# no change necessary
# batch 51 complete
# Original data: 0 empty frames
# no change necessary
# batch 52 complete
# Original data: 0 empty frames
# no change necessary
# batch 53 complete
# Original data: 0 empty frames
# no change necessary
# batch 54 complete
# Original data: 0 empty frames
# no change necessary
# batch 55 complete
# Original data: 0 empty frames
# no change necessary
# batch 56 complete
# Original data: 0 empty frames
# no change necessary
# batch 57 complete
# Original data: 0 empty frames
# no change necessary
# batch 58 complete
# Original data: 0 empty frames
# no change necessary
# batch 59 complete
# Original data: 0 empty frames
# no change necessary
# batch 60 complete
# Original data: 0 empty frames
# no change necessary
# batch 61 complete
# Original data: 0 empty frames
# no change necessary
# batch 62 complete
# Original data: 0 empty frames
# no change necessary
# batch 63 complete
# Original data: 0 empty frames
# no change necessary
# batch 64 complete
# Original data: 0 empty frames
# no change necessary
# batch 65 complete
# Original data: 0 empty frames
# no change necessary
# batch 66 complete
# Original data: 0 empty frames
# no change necessary
# batch 67 complete
# Original data: 0 empty frames
# no change necessary
# batch 68 complete
# Original data: 0 empty frames
# no change necessary
# batch 69 complete
# Original data: 0 empty frames
# no change necessary
# batch 70 complete
# Original data: 0 empty frames
# no change necessary
# batch 71 complete
# Original data: 0 empty frames
# no change necessary
# batch 72 complete
# Original data: 0 empty frames
# no change necessary
# batch 73 complete
# Original data: 0 empty frames
# no change necessary
# batch 74 complete
# Original data: 0 empty frames
# no change necessary
# batch 75 complete
# Original data: 0 empty frames
# no change necessary
# batch 76 complete
# Original data: 0 empty frames
# no change necessary
# batch 77 complete
# Original data: 0 empty frames
# no change necessary
# batch 78 complete
# Original data: 0 empty frames
# no change necessary
# batch 79 complete
# Original data: 0 empty frames
# no change necessary
# batch 80 complete
# Original data: 0 empty frames
# no change necessary
# batch 81 complete
# Original data: 0 empty frames
# no change necessary
# batch 82 complete
# Original data: 0 empty frames
# no change necessary
# batch 83 complete
# Original data: 0 empty frames
# no change necessary
# batch 84 complete
# Original data: 0 empty frames
# no change necessary
# batch 85 complete
# Original data: 0 empty frames
# no change necessary
# batch 86 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 87 complete
# Original data: 0 empty frames
# no change necessary
# batch 88 complete
# Original data: 0 empty frames
# no change necessary
# batch 89 complete
# Original data: 0 empty frames
# no change necessary
# batch 90 complete
# Original data: 0 empty frames
# no change necessary
# batch 91 complete
# Original data: 0 empty frames
# no change necessary
# batch 92 complete
# Original data: 0 empty frames
# no change necessary
# batch 93 complete
# Original data: 0 empty frames
# no change necessary
# batch 94 complete
# Original data: 0 empty frames
# no change necessary
# batch 95 complete
# Original data: 0 empty frames
# no change necessary
# batch 96 complete
# Original data: 0 empty frames
# no change necessary
# batch 97 complete
# Original data: 0 empty frames
# no change necessary
# batch 98 complete
# Original data: 0 empty frames
# no change necessary
# batch 99 complete
# Original data: 1 empty frames
# no change necessary
# batch 100 complete
# Original data: 0 empty frames
# no change necessary
# batch 101 complete
# Original data: 1 empty frames
# no change necessary
# batch 102 complete
# Original data: 0 empty frames
# no change necessary
# batch 103 complete
# Original data: 0 empty frames
# no change necessary
# batch 104 complete
# Original data: 0 empty frames
# no change necessary
# batch 105 complete
# Original data: 5 empty frames
# no change necessary
# batch 106 complete
# Original data: 19 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 107 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 108 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 4 empty frames
# batch 109 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 4 empty frames
# batch 110 complete
# Original data: 20 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 111 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 2 empty frames
# batch 112 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 113 complete
# Original data: 14 empty frames
# transformation completed
# Clockwise rotation; 14 empty frames
# too many missing frames, batch discarded
# batch 114 complete
# Original data: 28 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 115 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 116 complete
# Original data: 21 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 117 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 118 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 119 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 120 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 121 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 122 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 123 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 124 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 125 complete
# Original data: 21 empty frames
# transformation completed
# Clockwise rotation; 2 empty frames
# batch 126 complete
# Original data: 21 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 127 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 128 complete
# Original data: 2 empty frames
# no change necessary
# batch 129 complete
# Original data: 4 empty frames
# no change necessary
# batch 130 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 131 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 132 complete
# Original data: 18 empty frames
# transformation completed
# Clockwise rotation; 5 empty frames
# batch 133 complete
# Original data: 22 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 134 complete
# Original data: 16 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 135 complete
# Original data: 21 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 136 complete
# Original data: 22 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 137 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 138 complete
# Original data: 20 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 139 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 140 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 141 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 142 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 143 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 144 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 145 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 146 complete
# Original data: 22 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 147 complete
# Original data: 22 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 148 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 149 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 150 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 151 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 152 complete
# Original data: 19 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 153 complete
# Original data: 19 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 154 complete
# Original data: 24 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 155 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 156 complete
# Original data: 22 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 157 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 158 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 159 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 160 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 161 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 162 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 163 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 164 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 165 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 3 empty frames
# batch 166 complete
# Original data: 27 empty frames
# transformation completed
# Clockwise rotation; 11 empty frames
# too many missing frames, batch discarded
# batch 167 complete
# Original data: 23 empty frames
# transformation completed
# Clockwise rotation; 11 empty frames
# too many missing frames, batch discarded
# batch 168 complete
# Original data: 16 empty frames
# transformation completed
# Clockwise rotation; 9 empty frames
# too many missing frames, batch discarded
# batch 169 complete
# Original data: 15 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 170 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 171 complete
# Original data: 10 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 172 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 173 complete
# Original data: 10 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 174 complete
# Original data: 8 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 175 complete
# Original data: 4 empty frames
# no change necessary
# batch 176 complete
# Original data: 9 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 177 complete
# Original data: 5 empty frames
# no change necessary
# batch 178 complete
# Original data: 18 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 179 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 180 complete
# Original data: 17 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 181 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 182 complete
# Original data: 15 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 183 complete
# Original data: 21 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 184 complete
# Original data: 21 empty frames
# transformation completed
# Counterclockwise rotation; 4 empty frames
# batch 185 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 2 empty frames
# batch 186 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 187 complete
# Original data: 23 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 188 complete
# Original data: 27 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 189 complete
# Original data: 21 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 190 complete
# Original data: 28 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 191 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 192 complete
# Original data: 20 empty frames
# transformation completed
# Clockwise rotation; 2 empty frames
# batch 193 complete
# Original data: 19 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 194 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 195 complete
# Original data: 21 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 196 complete
# Original data: 23 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 197 complete
# Original data: 20 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 198 complete
# Original data: 24 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 199 complete
# Original data: 24 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 200 complete
# Original data: 20 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 201 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 202 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 203 complete
# Original data: 19 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 204 complete
# Original data: 14 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 205 complete
# Original data: 8 empty frames
# transformation completed
# Clockwise rotation; 2 empty frames
# batch 206 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 207 complete
# Original data: 10 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 208 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 209 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 210 complete
# Original data: 15 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 211 complete
# Original data: 19 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 212 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 5 empty frames
# batch 213 complete
# Original data: 16 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 214 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 215 complete
# Original data: 16 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 216 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 217 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 218 complete
# Original data: 9 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 219 complete
# Original data: 14 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 220 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 221 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 2 empty frames
# batch 222 complete
# Original data: 10 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 223 complete
# Original data: 18 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 224 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 225 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 226 complete
# Original data: 23 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 227 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 228 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 229 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 230 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 231 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 232 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 233 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 234 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 235 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 236 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 237 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 238 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 239 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 240 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 241 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 242 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 243 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 244 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 245 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 246 complete
# Original data: 19 empty frames
# transformation completed
# Clockwise rotation; 5 empty frames
# batch 247 complete
# Original data: 15 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 248 complete
# Original data: 8 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 249 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 250 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 251 complete
# Original data: 15 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 252 complete
# Original data: 18 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 253 complete
# Original data: 9 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 254 complete
# Original data: 8 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 255 complete
# Original data: 9 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 256 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 257 complete
# Original data: 10 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 258 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 259 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 260 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 261 complete
# Original data: 17 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 262 complete
# Original data: 16 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 263 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 264 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 265 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 266 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 267 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 268 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 269 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 270 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 271 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 272 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 273 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 274 complete
# Original data: 4 empty frames
# no change necessary
# batch 275 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 276 complete
# Original data: 4 empty frames
# no change necessary
# batch 277 complete
# Original data: 4 empty frames
# no change necessary
# batch 278 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 279 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 280 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 281 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 282 complete
# Original data: 3 empty frames
# no change necessary
# batch 283 complete
# Original data: 5 empty frames
# no change necessary
# batch 284 complete
# Original data: 0 empty frames
# no change necessary
# batch 285 complete
# =======================================================
# -----------Skeleton Data Extraction Complete-----------
# =======================================================
# Array shape: (8878, 17, 2)
# Data saved to: Free_Skel_Training.npy
# =======================================================
# CPU times: total: 1h 47min 3s
# Wall time: 19min 24s

# %%
# %%time
video = "C:/Users/jonso/OneDrive/Desktop/Fly Training Data.mp4"
path = 'Fly_Skel_Training.npy'
swimPose_estimate(video, path)
#counterclockwise
# Out:
# TF: 236
# Original data: 0 empty frames
# no change necessary
# batch 1 complete
# Original data: 0 empty frames
# no change necessary
# batch 2 complete
# Original data: 2 empty frames
# no change necessary
# batch 3 complete
# Original data: 0 empty frames
# no change necessary
# batch 4 complete
# Original data: 0 empty frames
# no change necessary
# batch 5 complete
# Original data: 0 empty frames
# no change necessary
# batch 6 complete
# Original data: 0 empty frames
# no change necessary
# batch 7 complete
# Original data: 0 empty frames
# no change necessary
# batch 8 complete
# Original data: 0 empty frames
# no change necessary
# batch 9 complete
# Original data: 0 empty frames
# no change necessary
# batch 10 complete
# Original data: 0 empty frames
# no change necessary
# batch 11 complete
# Original data: 0 empty frames
# no change necessary
# batch 12 complete
# Original data: 0 empty frames
# no change necessary
# batch 13 complete
# Original data: 1 empty frames
# no change necessary
# batch 14 complete
# Original data: 0 empty frames
# no change necessary
# batch 15 complete
# Original data: 0 empty frames
# no change necessary
# batch 16 complete
# Original data: 0 empty frames
# no change necessary
# batch 17 complete
# Original data: 1 empty frames
# no change necessary
# batch 18 complete
# Original data: 0 empty frames
# no change necessary
# batch 19 complete
# Original data: 0 empty frames
# no change necessary
# batch 20 complete
# Original data: 1 empty frames
# no change necessary
# batch 21 complete
# Original data: 0 empty frames
# no change necessary
# batch 22 complete
# Original data: 2 empty frames
# no change necessary
# batch 23 complete
# Original data: 2 empty frames
# no change necessary
# batch 24 complete
# Original data: 0 empty frames
# no change necessary
# batch 25 complete
# Original data: 0 empty frames
# no change necessary
# batch 26 complete
# Original data: 0 empty frames
# no change necessary
# batch 27 complete
# Original data: 0 empty frames
# no change necessary
# batch 28 complete
# Original data: 0 empty frames
# no change necessary
# batch 29 complete
# Original data: 0 empty frames
# no change necessary
# batch 30 complete
# Original data: 0 empty frames
# no change necessary
# batch 31 complete
# Original data: 0 empty frames
# no change necessary
# batch 32 complete
# Original data: 3 empty frames
# no change necessary
# batch 33 complete
# Original data: 0 empty frames
# no change necessary
# batch 34 complete
# Original data: 0 empty frames
# no change necessary
# batch 35 complete
# Original data: 0 empty frames
# no change necessary
# batch 36 complete
# Original data: 0 empty frames
# no change necessary
# batch 37 complete
# Original data: 0 empty frames
# no change necessary
# batch 38 complete
# Original data: 0 empty frames
# no change necessary
# batch 39 complete
# Original data: 4 empty frames
# no change necessary
# batch 40 complete
# Original data: 4 empty frames
# no change necessary
# batch 41 complete
# Original data: 5 empty frames
# no change necessary
# batch 42 complete
# Original data: 0 empty frames
# no change necessary
# batch 43 complete
# Original data: 0 empty frames
# no change necessary
# batch 44 complete
# Original data: 0 empty frames
# no change necessary
# batch 45 complete
# Original data: 0 empty frames
# no change necessary
# batch 46 complete
# Original data: 0 empty frames
# no change necessary
# batch 47 complete
# Original data: 0 empty frames
# no change necessary
# batch 48 complete
# Original data: 0 empty frames
# no change necessary
# batch 49 complete
# Original data: 0 empty frames
# no change necessary
# batch 50 complete
# Original data: 4 empty frames
# no change necessary
# batch 51 complete
# Original data: 5 empty frames
# no change necessary
# batch 52 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 2 empty frames
# batch 53 complete
# Original data: 0 empty frames
# no change necessary
# batch 54 complete
# Original data: 0 empty frames
# no change necessary
# batch 55 complete
# Original data: 0 empty frames
# no change necessary
# batch 56 complete
# Original data: 0 empty frames
# no change necessary
# batch 57 complete
# Original data: 0 empty frames
# no change necessary
# batch 58 complete
# Original data: 0 empty frames
# no change necessary
# batch 59 complete
# Original data: 0 empty frames
# no change necessary
# batch 60 complete
# Original data: 2 empty frames
# no change necessary
# batch 61 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 15 empty frames
# too many missing frames, batch discarded
# batch 62 complete
# Original data: 0 empty frames
# no change necessary
# batch 63 complete
# Original data: 0 empty frames
# no change necessary
# batch 64 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 2 empty frames
# batch 65 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 13 empty frames
# too many missing frames, batch discarded
# batch 66 complete
# Original data: 0 empty frames
# no change necessary
# batch 67 complete
# Original data: 0 empty frames
# no change necessary
# batch 68 complete
# Original data: 0 empty frames
# no change necessary
# batch 69 complete
# Original data: 0 empty frames
# no change necessary
# batch 70 complete
# Original data: 0 empty frames
# no change necessary
# batch 71 complete
# Original data: 5 empty frames
# no change necessary
# batch 72 complete
# Original data: 0 empty frames
# no change necessary
# batch 73 complete
# Original data: 2 empty frames
# no change necessary
# batch 74 complete
# Original data: 0 empty frames
# no change necessary
# batch 75 complete
# Original data: 0 empty frames
# no change necessary
# batch 76 complete
# Original data: 3 empty frames
# no change necessary
# batch 77 complete
# Original data: 0 empty frames
# no change necessary
# batch 78 complete
# Original data: 0 empty frames
# no change necessary
# batch 79 complete
# Original data: 5 empty frames
# no change necessary
# batch 80 complete
# Original data: 2 empty frames
# no change necessary
# batch 81 complete
# Original data: 0 empty frames
# no change necessary
# batch 82 complete
# Original data: 0 empty frames
# no change necessary
# batch 83 complete
# Original data: 1 empty frames
# no change necessary
# batch 84 complete
# Original data: 0 empty frames
# no change necessary
# batch 85 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 3 empty frames
# batch 86 complete
# Original data: 4 empty frames
# no change necessary
# batch 87 complete
# Original data: 0 empty frames
# no change necessary
# batch 88 complete
# Original data: 0 empty frames
# no change necessary
# batch 89 complete
# Original data: 0 empty frames
# no change necessary
# batch 90 complete
# Original data: 0 empty frames
# no change necessary
# batch 91 complete
# Original data: 0 empty frames
# no change necessary
# batch 92 complete
# Original data: 0 empty frames
# no change necessary
# batch 93 complete
# Original data: 0 empty frames
# no change necessary
# batch 94 complete
# Original data: 5 empty frames
# no change necessary
# batch 95 complete
# Original data: 20 empty frames
# transformation completed
# Counterclockwise rotation; 15 empty frames
# too many missing frames, batch discarded
# batch 96 complete
# Original data: 4 empty frames
# no change necessary
# batch 97 complete
# Original data: 1 empty frames
# no change necessary
# batch 98 complete
# Original data: 0 empty frames
# no change necessary
# batch 99 complete
# Original data: 0 empty frames
# no change necessary
# batch 100 complete
# Original data: 1 empty frames
# no change necessary
# batch 101 complete
# Original data: 4 empty frames
# no change necessary
# batch 102 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 18 empty frames
# too many missing frames, batch discarded
# batch 103 complete
# Original data: 2 empty frames
# no change necessary
# batch 104 complete
# Original data: 5 empty frames
# no change necessary
# batch 105 complete
# Original data: 0 empty frames
# no change necessary
# batch 106 complete
# Original data: 0 empty frames
# no change necessary
# batch 107 complete
# Original data: 0 empty frames
# no change necessary
# batch 108 complete
# Original data: 0 empty frames
# no change necessary
# batch 109 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 13 empty frames
# too many missing frames, batch discarded
# batch 110 complete
# Original data: 1 empty frames
# no change necessary
# batch 111 complete
# Original data: 0 empty frames
# no change necessary
# batch 112 complete
# Original data: 0 empty frames
# no change necessary
# batch 113 complete
# Original data: 2 empty frames
# no change necessary
# batch 114 complete
# Original data: 4 empty frames
# no change necessary
# batch 115 complete
# Original data: 0 empty frames
# no change necessary
# batch 116 complete
# Original data: 0 empty frames
# no change necessary
# batch 117 complete
# Original data: 0 empty frames
# no change necessary
# batch 118 complete
# Original data: 3 empty frames
# no change necessary
# batch 119 complete
# Original data: 0 empty frames
# no change necessary
# batch 120 complete
# Original data: 0 empty frames
# no change necessary
# batch 121 complete
# Original data: 0 empty frames
# no change necessary
# batch 122 complete
# Original data: 0 empty frames
# no change necessary
# batch 123 complete
# Original data: 0 empty frames
# no change necessary
# batch 124 complete
# Original data: 5 empty frames
# no change necessary
# batch 125 complete
# Original data: 2 empty frames
# no change necessary
# batch 126 complete
# Original data: 0 empty frames
# no change necessary
# batch 127 complete
# Original data: 0 empty frames
# no change necessary
# batch 128 complete
# Original data: 0 empty frames
# no change necessary
# batch 129 complete
# Original data: 1 empty frames
# no change necessary
# batch 130 complete
# Original data: 0 empty frames
# no change necessary
# batch 131 complete
# Original data: 0 empty frames
# no change necessary
# batch 132 complete
# Original data: 0 empty frames
# no change necessary
# batch 133 complete
# Original data: 0 empty frames
# no change necessary
# batch 134 complete
# Original data: 0 empty frames
# no change necessary
# batch 135 complete
# Original data: 0 empty frames
# no change necessary
# batch 136 complete
# Original data: 0 empty frames
# no change necessary
# batch 137 complete
# Original data: 0 empty frames
# no change necessary
# batch 138 complete
# Original data: 0 empty frames
# no change necessary
# batch 139 complete
# Original data: 0 empty frames
# no change necessary
# batch 140 complete
# Original data: 0 empty frames
# no change necessary
# batch 141 complete
# Original data: 1 empty frames
# no change necessary
# batch 142 complete
# Original data: 0 empty frames
# no change necessary
# batch 143 complete
# Original data: 2 empty frames
# no change necessary
# batch 144 complete
# Original data: 0 empty frames
# no change necessary
# batch 145 complete
# Original data: 0 empty frames
# no change necessary
# batch 146 complete
# Original data: 0 empty frames
# no change necessary
# batch 147 complete
# Original data: 0 empty frames
# no change necessary
# batch 148 complete
# Original data: 0 empty frames
# no change necessary
# batch 149 complete
# Original data: 0 empty frames
# no change necessary
# batch 150 complete
# Original data: 0 empty frames
# no change necessary
# batch 151 complete
# Original data: 0 empty frames
# no change necessary
# batch 152 complete
# Original data: 0 empty frames
# no change necessary
# batch 153 complete
# Original data: 0 empty frames
# no change necessary
# batch 154 complete
# Original data: 0 empty frames
# no change necessary
# batch 155 complete
# Original data: 0 empty frames
# no change necessary
# batch 156 complete
# Original data: 0 empty frames
# no change necessary
# batch 157 complete
# Original data: 0 empty frames
# no change necessary
# batch 158 complete
# Original data: 1 empty frames
# no change necessary
# batch 159 complete
# Original data: 0 empty frames
# no change necessary
# batch 160 complete
# Original data: 0 empty frames
# no change necessary
# batch 161 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 162 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 9 empty frames
# too many missing frames, batch discarded
# batch 163 complete
# Original data: 23 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 164 complete
# Original data: 17 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 165 complete
# Original data: 1 empty frames
# no change necessary
# batch 166 complete
# Original data: 5 empty frames
# no change necessary
# batch 167 complete
# Original data: 2 empty frames
# no change necessary
# batch 168 complete
# Original data: 1 empty frames
# no change necessary
# batch 169 complete
# Original data: 2 empty frames
# no change necessary
# batch 170 complete
# Original data: 5 empty frames
# no change necessary
# batch 171 complete
# Original data: 4 empty frames
# no change necessary
# batch 172 complete
# Original data: 1 empty frames
# no change necessary
# batch 173 complete
# Original data: 3 empty frames
# no change necessary
# batch 174 complete
# Original data: 10 empty frames
# transformation completed
# Clockwise rotation; 2 empty frames
# batch 175 complete
# Original data: 5 empty frames
# no change necessary
# batch 176 complete
# Original data: 5 empty frames
# no change necessary
# batch 177 complete
# Original data: 8 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 178 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 179 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 180 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 3 empty frames
# batch 181 complete
# Original data: 15 empty frames
# transformation completed
# Clockwise rotation; 5 empty frames
# batch 182 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 4 empty frames
# batch 183 complete
# Original data: 2 empty frames
# no change necessary
# batch 184 complete
# Original data: 1 empty frames
# no change necessary
# batch 185 complete
# Original data: 0 empty frames
# no change necessary
# batch 186 complete
# Original data: 5 empty frames
# no change necessary
# batch 187 complete
# Original data: 3 empty frames
# no change necessary
# batch 188 complete
# Original data: 2 empty frames
# no change necessary
# batch 189 complete
# Original data: 4 empty frames
# no change necessary
# batch 190 complete
# Original data: 5 empty frames
# no change necessary
# batch 191 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 2 empty frames
# batch 192 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 4 empty frames
# batch 193 complete
# Original data: 5 empty frames
# no change necessary
# batch 194 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 3 empty frames
# batch 195 complete
# Original data: 5 empty frames
# no change necessary
# batch 196 complete
# Original data: 3 empty frames
# no change necessary
# batch 197 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 4 empty frames
# batch 198 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 199 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 200 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 201 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 202 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 203 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 204 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 205 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 206 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 207 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 208 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 209 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 210 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 211 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 212 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 213 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 214 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 215 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 216 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 217 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 4 empty frames
# batch 218 complete
# Original data: 4 empty frames
# no change necessary
# batch 219 complete
# Original data: 1 empty frames
# no change necessary
# batch 220 complete
# Original data: 8 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 221 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 222 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 223 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 224 complete
# Original data: 5 empty frames
# no change necessary
# batch 225 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 226 complete
# Original data: 14 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 227 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 228 complete
# Original data: 9 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 229 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 230 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 231 complete
# Original data: 9 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 232 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 233 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 234 complete
# Original data: 21 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 235 complete
# Original data: 24 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 236 complete
# =======================================================
# -----------Skeleton Data Extraction Complete-----------
# =======================================================
# Array shape: (7136, 17, 2)
# Data saved to: Fly_Skel_Training.npy
# =======================================================
# CPU times: total: 1h 6min 57s
# Wall time: 12min 1s

# %%
# %%time
video = "C:/Users/jonso/OneDrive/Desktop/Back Training Data.mp4"
path = 'Back_Skel_Training.npy'
swimPose_estimate(video, path)
#counterclockwise
# Out:
# TF: 231
# Original data: 0 empty frames
# no change necessary
# batch 1 complete
# Original data: 0 empty frames
# no change necessary
# batch 2 complete
# Original data: 0 empty frames
# no change necessary
# batch 3 complete
# Original data: 0 empty frames
# no change necessary
# batch 4 complete
# Original data: 0 empty frames
# no change necessary
# batch 5 complete
# Original data: 2 empty frames
# no change necessary
# batch 6 complete
# Original data: 5 empty frames
# no change necessary
# batch 7 complete
# Original data: 8 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 8 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 9 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 10 complete
# Original data: 0 empty frames
# no change necessary
# batch 11 complete
# Original data: 0 empty frames
# no change necessary
# batch 12 complete
# Original data: 0 empty frames
# no change necessary
# batch 13 complete
# Original data: 0 empty frames
# no change necessary
# batch 14 complete
# Original data: 2 empty frames
# no change necessary
# batch 15 complete
# Original data: 0 empty frames
# no change necessary
# batch 16 complete
# Original data: 1 empty frames
# no change necessary
# batch 17 complete
# Original data: 2 empty frames
# no change necessary
# batch 18 complete
# Original data: 3 empty frames
# no change necessary
# batch 19 complete
# Original data: 2 empty frames
# no change necessary
# batch 20 complete
# Original data: 2 empty frames
# no change necessary
# batch 21 complete
# Original data: 0 empty frames
# no change necessary
# batch 22 complete
# Original data: 0 empty frames
# no change necessary
# batch 23 complete
# Original data: 0 empty frames
# no change necessary
# batch 24 complete
# Original data: 2 empty frames
# no change necessary
# batch 25 complete
# Original data: 4 empty frames
# no change necessary
# batch 26 complete
# Original data: 0 empty frames
# no change necessary
# batch 27 complete
# Original data: 0 empty frames
# no change necessary
# batch 28 complete
# Original data: 0 empty frames
# no change necessary
# batch 29 complete
# Original data: 0 empty frames
# no change necessary
# batch 30 complete
# Original data: 0 empty frames
# no change necessary
# batch 31 complete
# Original data: 0 empty frames
# no change necessary
# batch 32 complete
# Original data: 1 empty frames
# no change necessary
# batch 33 complete
# Original data: 1 empty frames
# no change necessary
# batch 34 complete
# Original data: 0 empty frames
# no change necessary
# batch 35 complete
# Original data: 0 empty frames
# no change necessary
# batch 36 complete
# Original data: 0 empty frames
# no change necessary
# batch 37 complete
# Original data: 0 empty frames
# no change necessary
# batch 38 complete
# Original data: 0 empty frames
# no change necessary
# batch 39 complete
# Original data: 2 empty frames
# no change necessary
# batch 40 complete
# Original data: 0 empty frames
# no change necessary
# batch 41 complete
# Original data: 1 empty frames
# no change necessary
# batch 42 complete
# Original data: 0 empty frames
# no change necessary
# batch 43 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 44 complete
# Original data: 0 empty frames
# no change necessary
# batch 45 complete
# Original data: 0 empty frames
# no change necessary
# batch 46 complete
# Original data: 3 empty frames
# no change necessary
# batch 47 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 7 empty frames
# too many missing frames, batch discarded
# batch 48 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 3 empty frames
# batch 49 complete
# Original data: 10 empty frames
# transformation completed
# Clockwise rotation; 3 empty frames
# batch 50 complete
# Original data: 4 empty frames
# no change necessary
# batch 51 complete
# Original data: 2 empty frames
# no change necessary
# batch 52 complete
# Original data: 0 empty frames
# no change necessary
# batch 53 complete
# Original data: 1 empty frames
# no change necessary
# batch 54 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 55 complete
# Original data: 14 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 56 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 8 empty frames
# too many missing frames, batch discarded
# batch 57 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 7 empty frames
# too many missing frames, batch discarded
# batch 58 complete
# Original data: 4 empty frames
# no change necessary
# batch 59 complete
# Original data: 2 empty frames
# no change necessary
# batch 60 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 61 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 4 empty frames
# batch 62 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 4 empty frames
# batch 63 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 5 empty frames
# batch 64 complete
# Original data: 0 empty frames
# no change necessary
# batch 65 complete
# Original data: 2 empty frames
# no change necessary
# batch 66 complete
# Original data: 1 empty frames
# no change necessary
# batch 67 complete
# Original data: 0 empty frames
# no change necessary
# batch 68 complete
# Original data: 0 empty frames
# no change necessary
# batch 69 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 70 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 71 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 11 empty frames
# too many missing frames, batch discarded
# batch 72 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 73 complete
# Original data: 5 empty frames
# no change necessary
# batch 74 complete
# Original data: 2 empty frames
# no change necessary
# batch 75 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 76 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 77 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 78 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 79 complete
# Original data: 2 empty frames
# no change necessary
# batch 80 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 81 complete
# Original data: 0 empty frames
# no change necessary
# batch 82 complete
# Original data: 1 empty frames
# no change necessary
# batch 83 complete
# Original data: 0 empty frames
# no change necessary
# batch 84 complete
# Original data: 2 empty frames
# no change necessary
# batch 85 complete
# Original data: 5 empty frames
# no change necessary
# batch 86 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 87 complete
# Original data: 5 empty frames
# no change necessary
# batch 88 complete
# Original data: 5 empty frames
# no change necessary
# batch 89 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 90 complete
# Original data: 3 empty frames
# no change necessary
# batch 91 complete
# Original data: 0 empty frames
# no change necessary
# batch 92 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 93 complete
# Original data: 0 empty frames
# no change necessary
# batch 94 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 95 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 2 empty frames
# batch 96 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 97 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 10 empty frames
# too many missing frames, batch discarded
# batch 98 complete
# Original data: 1 empty frames
# no change necessary
# batch 99 complete
# Original data: 1 empty frames
# no change necessary
# batch 100 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 101 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 102 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 103 complete
# Original data: 0 empty frames
# no change necessary
# batch 104 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 105 complete
# Original data: 2 empty frames
# no change necessary
# batch 106 complete
# Original data: 0 empty frames
# no change necessary
# batch 107 complete
# Original data: 0 empty frames
# no change necessary
# batch 108 complete
# Original data: 0 empty frames
# no change necessary
# batch 109 complete
# Original data: 0 empty frames
# no change necessary
# batch 110 complete
# Original data: 0 empty frames
# no change necessary
# batch 111 complete
# Original data: 0 empty frames
# no change necessary
# batch 112 complete
# Original data: 0 empty frames
# no change necessary
# batch 113 complete
# Original data: 0 empty frames
# no change necessary
# batch 114 complete
# Original data: 0 empty frames
# no change necessary
# batch 115 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 116 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 117 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 118 complete
# Original data: 0 empty frames
# no change necessary
# batch 119 complete
# Original data: 0 empty frames
# no change necessary
# batch 120 complete
# Original data: 0 empty frames
# no change necessary
# batch 121 complete
# Original data: 0 empty frames
# no change necessary
# batch 122 complete
# Original data: 0 empty frames
# no change necessary
# batch 123 complete
# Original data: 0 empty frames
# no change necessary
# batch 124 complete
# Original data: 0 empty frames
# no change necessary
# batch 125 complete
# Original data: 0 empty frames
# no change necessary
# batch 126 complete
# Original data: 0 empty frames
# no change necessary
# batch 127 complete
# Original data: 0 empty frames
# no change necessary
# batch 128 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 129 complete
# Original data: 18 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 130 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 131 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 132 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 133 complete
# Original data: 0 empty frames
# no change necessary
# batch 134 complete
# Original data: 0 empty frames
# no change necessary
# batch 135 complete
# Original data: 0 empty frames
# no change necessary
# batch 136 complete
# Original data: 0 empty frames
# no change necessary
# batch 137 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 138 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 139 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 140 complete
# Original data: 10 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 141 complete
# Original data: 0 empty frames
# no change necessary
# batch 142 complete
# Original data: 0 empty frames
# no change necessary
# batch 143 complete
# Original data: 0 empty frames
# no change necessary
# batch 144 complete
# Original data: 2 empty frames
# no change necessary
# batch 145 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 146 complete
# Original data: 4 empty frames
# no change necessary
# batch 147 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 148 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 149 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 150 complete
# Original data: 10 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 151 complete
# Original data: 14 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 152 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 153 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 154 complete
# Original data: 10 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 155 complete
# Original data: 16 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 156 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 157 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 158 complete
# Original data: 9 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 159 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 160 complete
# Original data: 14 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 161 complete
# Original data: 5 empty frames
# no change necessary
# batch 162 complete
# Original data: 16 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 163 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 4 empty frames
# batch 164 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 165 complete
# Original data: 19 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 166 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 167 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 168 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 169 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 170 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 171 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 172 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 173 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 174 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 175 complete
# Original data: 2 empty frames
# no change necessary
# batch 176 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 177 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 178 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 179 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 180 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 181 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 182 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 183 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 184 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 2 empty frames
# batch 185 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 186 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 187 complete
# Original data: 0 empty frames
# no change necessary
# batch 188 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 189 complete
# Original data: 3 empty frames
# no change necessary
# batch 190 complete
# Original data: 22 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 191 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 192 complete
# Original data: 14 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 193 complete
# Original data: 9 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 194 complete
# Original data: 22 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 195 complete
# Original data: 9 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 196 complete
# Original data: 21 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 197 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 198 complete
# Original data: 23 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 199 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 200 complete
# Original data: 19 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 201 complete
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 202 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 203 complete
# Original data: 5 empty frames
# no change necessary
# batch 204 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 205 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 206 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 207 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 208 complete
# Original data: 14 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 209 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 210 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 211 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 212 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 213 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 214 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 215 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 216 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 217 complete
# Original data: 18 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 218 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 219 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 220 complete
# Original data: 17 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 221 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 222 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 223 complete
# Original data: 3 empty frames
# no change necessary
# batch 224 complete
# Original data: 4 empty frames
# no change necessary
# batch 225 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 226 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 227 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 228 complete
# Original data: 0 empty frames
# no change necessary
# batch 229 complete
# Original data: 15 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 230 complete
# Original data: 24 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 231 complete
# =======================================================
# -----------Skeleton Data Extraction Complete-----------
# =======================================================
# Array shape: (7087, 17, 2)
# Data saved to: Back_Skel_Training.npy
# =======================================================
# CPU times: total: 1h 18min 58s
# Wall time: 14min 21s

# %%
# %%time
video = "C:/Users/jonso/OneDrive/Desktop/Breast Training Data.mp4"
path = 'Breast_Skel_Training.npy'
swimPose_estimate(video, path)
#counterclockwise
# Out:
# TF: 223
# Original data: 3 empty frames
# no change necessary
# batch 1 complete
# Original data: 3 empty frames
# no change necessary
# batch 2 complete
# Original data: 0 empty frames
# no change necessary
# batch 3 complete
# Original data: 0 empty frames
# no change necessary
# batch 4 complete
# Original data: 0 empty frames
# no change necessary
# batch 5 complete
# Original data: 3 empty frames
# no change necessary
# batch 6 complete
# Original data: 2 empty frames
# no change necessary
# batch 7 complete
# Original data: 0 empty frames
# no change necessary
# batch 8 complete
# Original data: 2 empty frames
# no change necessary
# batch 9 complete
# Original data: 2 empty frames
# no change necessary
# batch 10 complete
# Original data: 0 empty frames
# no change necessary
# batch 11 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 3 empty frames
# batch 12 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 9 empty frames
# too many missing frames, batch discarded
# batch 13 complete
# Original data: 0 empty frames
# no change necessary
# batch 14 complete
# Original data: 0 empty frames
# no change necessary
# batch 15 complete
# Original data: 0 empty frames
# no change necessary
# batch 16 complete
# Original data: 0 empty frames
# no change necessary
# batch 17 complete
# Original data: 0 empty frames
# no change necessary
# batch 18 complete
# Original data: 0 empty frames
# no change necessary
# batch 19 complete
# Original data: 0 empty frames
# no change necessary
# batch 20 complete
# Original data: 0 empty frames
# no change necessary
# batch 21 complete
# Original data: 0 empty frames
# no change necessary
# batch 22 complete
# Original data: 3 empty frames
# no change necessary
# batch 23 complete
# Original data: 0 empty frames
# no change necessary
# batch 24 complete
# Original data: 0 empty frames
# no change necessary
# batch 25 complete
# Original data: 0 empty frames
# no change necessary
# batch 26 complete
# Original data: 0 empty frames
# no change necessary
# batch 27 complete
# Original data: 0 empty frames
# no change necessary
# batch 28 complete
# Original data: 0 empty frames
# no change necessary
# batch 29 complete
# Original data: 0 empty frames
# no change necessary
# batch 30 complete
# Original data: 4 empty frames
# no change necessary
# batch 31 complete
# Original data: 0 empty frames
# no change necessary
# batch 32 complete
# Original data: 0 empty frames
# no change necessary
# batch 33 complete
# Original data: 0 empty frames
# no change necessary
# batch 34 complete
# Original data: 1 empty frames
# no change necessary
# batch 35 complete
# Original data: 5 empty frames
# no change necessary
# batch 36 complete
# Original data: 0 empty frames
# no change necessary
# batch 37 complete
# Original data: 0 empty frames
# no change necessary
# batch 38 complete
# Original data: 3 empty frames
# no change necessary
# batch 39 complete
# Original data: 2 empty frames
# no change necessary
# batch 40 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 41 complete
# Original data: 1 empty frames
# no change necessary
# batch 42 complete
# Original data: 2 empty frames
# no change necessary
# batch 43 complete
# Original data: 1 empty frames
# no change necessary
# batch 44 complete
# Original data: 0 empty frames
# no change necessary
# batch 45 complete
# Original data: 4 empty frames
# no change necessary
# batch 46 complete
# Original data: 2 empty frames
# no change necessary
# batch 47 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 48 complete
# Original data: 0 empty frames
# no change necessary
# batch 49 complete
# Original data: 1 empty frames
# no change necessary
# batch 50 complete
# Original data: 2 empty frames
# no change necessary
# batch 51 complete
# Original data: 0 empty frames
# no change necessary
# batch 52 complete
# Original data: 2 empty frames
# no change necessary
# batch 53 complete
# Original data: 3 empty frames
# no change necessary
# batch 54 complete
# Original data: 0 empty frames
# no change necessary
# batch 55 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 56 complete
# Original data: 0 empty frames
# no change necessary
# batch 57 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 58 complete
# Original data: 0 empty frames
# no change necessary
# batch 59 complete
# Original data: 0 empty frames
# no change necessary
# batch 60 complete
# Original data: 0 empty frames
# no change necessary
# batch 61 complete
# Original data: 0 empty frames
# no change necessary
# batch 62 complete
# Original data: 4 empty frames
# no change necessary
# batch 63 complete
# Original data: 0 empty frames
# no change necessary
# batch 64 complete
# Original data: 3 empty frames
# no change necessary
# batch 65 complete
# Original data: 0 empty frames
# no change necessary
# batch 66 complete
# Original data: 2 empty frames
# no change necessary
# batch 67 complete
# Original data: 3 empty frames
# no change necessary
# batch 68 complete
# Original data: 0 empty frames
# no change necessary
# batch 69 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 70 complete
# Original data: 0 empty frames
# no change necessary
# batch 71 complete
# Original data: 8 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 72 complete
# Original data: 5 empty frames
# no change necessary
# batch 73 complete
# Original data: 0 empty frames
# no change necessary
# batch 74 complete
# Original data: 2 empty frames
# no change necessary
# batch 75 complete
# Original data: 0 empty frames
# no change necessary
# batch 76 complete
# Original data: 4 empty frames
# no change necessary
# batch 77 complete
# Original data: 0 empty frames
# no change necessary
# batch 78 complete
# Original data: 0 empty frames
# no change necessary
# batch 79 complete
# Original data: 0 empty frames
# no change necessary
# batch 80 complete
# Original data: 0 empty frames
# no change necessary
# batch 81 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 82 complete
# Original data: 3 empty frames
# no change necessary
# batch 83 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 84 complete
# Original data: 0 empty frames
# no change necessary
# batch 85 complete
# Original data: 4 empty frames
# no change necessary
# batch 86 complete
# Original data: 0 empty frames
# no change necessary
# batch 87 complete
# Original data: 0 empty frames
# no change necessary
# batch 88 complete
# Original data: 1 empty frames
# no change necessary
# batch 89 complete
# Original data: 0 empty frames
# no change necessary
# batch 90 complete
# Original data: 2 empty frames
# no change necessary
# batch 91 complete
# Original data: 2 empty frames
# no change necessary
# batch 92 complete
# Original data: 0 empty frames
# no change necessary
# batch 93 complete
# Original data: 0 empty frames
# no change necessary
# batch 94 complete
# Original data: 2 empty frames
# no change necessary
# batch 95 complete
# Original data: 1 empty frames
# no change necessary
# batch 96 complete
# Original data: 0 empty frames
# no change necessary
# batch 97 complete
# Original data: 0 empty frames
# no change necessary
# batch 98 complete
# Original data: 0 empty frames
# no change necessary
# batch 99 complete
# Original data: 0 empty frames
# no change necessary
# batch 100 complete
# Original data: 1 empty frames
# no change necessary
# batch 101 complete
# Original data: 0 empty frames
# no change necessary
# batch 102 complete
# Original data: 2 empty frames
# no change necessary
# batch 103 complete
# Original data: 1 empty frames
# no change necessary
# batch 104 complete
# Original data: 0 empty frames
# no change necessary
# batch 105 complete
# Original data: 0 empty frames
# no change necessary
# batch 106 complete
# Original data: 1 empty frames
# no change necessary
# batch 107 complete
# Original data: 2 empty frames
# no change necessary
# batch 108 complete
# Original data: 2 empty frames
# no change necessary
# batch 109 complete
# Original data: 0 empty frames
# no change necessary
# batch 110 complete
# Original data: 0 empty frames
# no change necessary
# batch 111 complete
# Original data: 0 empty frames
# no change necessary
# batch 112 complete
# Original data: 0 empty frames
# no change necessary
# batch 113 complete
# Original data: 1 empty frames
# no change necessary
# batch 114 complete
# Original data: 0 empty frames
# no change necessary
# batch 115 complete
# Original data: 0 empty frames
# no change necessary
# batch 116 complete
# Original data: 0 empty frames
# no change necessary
# batch 117 complete
# Original data: 0 empty frames
# no change necessary
# batch 118 complete
# Original data: 0 empty frames
# no change necessary
# batch 119 complete
# Original data: 0 empty frames
# no change necessary
# batch 120 complete
# Original data: 0 empty frames
# no change necessary
# batch 121 complete
# Original data: 0 empty frames
# no change necessary
# batch 122 complete
# Original data: 0 empty frames
# no change necessary
# batch 123 complete
# Original data: 0 empty frames
# no change necessary
# batch 124 complete
# Original data: 0 empty frames
# no change necessary
# batch 125 complete
# Original data: 0 empty frames
# no change necessary
# batch 126 complete
# Original data: 0 empty frames
# no change necessary
# batch 127 complete
# Original data: 0 empty frames
# no change necessary
# batch 128 complete
# Original data: 0 empty frames
# no change necessary
# batch 129 complete
# Original data: 0 empty frames
# no change necessary
# batch 130 complete
# Original data: 0 empty frames
# no change necessary
# batch 131 complete
# Original data: 0 empty frames
# no change necessary
# batch 132 complete
# Original data: 0 empty frames
# no change necessary
# batch 133 complete
# Original data: 0 empty frames
# no change necessary
# batch 134 complete
# Original data: 0 empty frames
# no change necessary
# batch 135 complete
# Original data: 0 empty frames
# no change necessary
# batch 136 complete
# Original data: 1 empty frames
# no change necessary
# batch 137 complete
# Original data: 0 empty frames
# no change necessary
# batch 138 complete
# Original data: 0 empty frames
# no change necessary
# batch 139 complete
# Original data: 0 empty frames
# no change necessary
# batch 140 complete
# Original data: 0 empty frames
# no change necessary
# batch 141 complete
# Original data: 0 empty frames
# no change necessary
# batch 142 complete
# Original data: 0 empty frames
# no change necessary
# batch 143 complete
# Original data: 0 empty frames
# no change necessary
# batch 144 complete
# Original data: 0 empty frames
# no change necessary
# batch 145 complete
# Original data: 0 empty frames
# no change necessary
# batch 146 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 147 complete
# Original data: 27 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 148 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 6 empty frames
# too many missing frames, batch discarded
# batch 149 complete
# Original data: 22 empty frames
# transformation completed
# Counterclockwise rotation; 7 empty frames
# too many missing frames, batch discarded
# batch 150 complete
# Original data: 19 empty frames
# transformation completed
# Counterclockwise rotation; 13 empty frames
# too many missing frames, batch discarded
# batch 151 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 6 empty frames
# too many missing frames, batch discarded
# batch 152 complete
# Original data: 2 empty frames
# no change necessary
# batch 153 complete
# Original data: 0 empty frames
# no change necessary
# batch 154 complete
# Original data: 0 empty frames
# no change necessary
# batch 155 complete
# Original data: 0 empty frames
# no change necessary
# batch 156 complete
# Original data: 0 empty frames
# no change necessary
# batch 157 complete
# Original data: 0 empty frames
# no change necessary
# batch 158 complete
# Original data: 0 empty frames
# no change necessary
# batch 159 complete
# Original data: 0 empty frames
# no change necessary
# batch 160 complete
# Original data: 0 empty frames
# no change necessary
# batch 161 complete
# Original data: 0 empty frames
# no change necessary
# batch 162 complete
# Original data: 0 empty frames
# no change necessary
# batch 163 complete
# Original data: 3 empty frames
# no change necessary
# batch 164 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 165 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 166 complete
# Original data: 4 empty frames
# no change necessary
# batch 167 complete
# Original data: 2 empty frames
# no change necessary
# batch 168 complete
# Original data: 0 empty frames
# no change necessary
# batch 169 complete
# Original data: 0 empty frames
# no change necessary
# batch 170 complete
# Original data: 0 empty frames
# no change necessary
# batch 171 complete
# Original data: 0 empty frames
# no change necessary
# batch 172 complete
# Original data: 0 empty frames
# no change necessary
# batch 173 complete
# Original data: 3 empty frames
# no change necessary
# batch 174 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 175 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 176 complete
# Original data: 8 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 177 complete
# Original data: 3 empty frames
# no change necessary
# batch 178 complete
# Original data: 0 empty frames
# no change necessary
# batch 179 complete
# Original data: 0 empty frames
# no change necessary
# batch 180 complete
# Original data: 0 empty frames
# no change necessary
# batch 181 complete
# Original data: 0 empty frames
# no change necessary
# batch 182 complete
# Original data: 0 empty frames
# no change necessary
# batch 183 complete
# Original data: 0 empty frames
# no change necessary
# batch 184 complete
# Original data: 0 empty frames
# no change necessary
# batch 185 complete
# Original data: 0 empty frames
# no change necessary
# batch 186 complete
# Original data: 2 empty frames
# no change necessary
# batch 187 complete
# Original data: 0 empty frames
# no change necessary
# batch 188 complete
# Original data: 0 empty frames
# no change necessary
# batch 189 complete
# Original data: 3 empty frames
# no change necessary
# batch 190 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 191 complete
# Original data: 10 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 192 complete
# Original data: 2 empty frames
# no change necessary
# batch 193 complete
# Original data: 2 empty frames
# no change necessary
# batch 194 complete
# Original data: 17 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 195 complete
# Original data: 12 empty frames
# transformation completed
# Counterclockwise rotation; 2 empty frames
# batch 196 complete
# Original data: 26 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 197 complete
# Original data: 18 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 198 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 16 empty frames
# too many missing frames, batch discarded
# batch 199 complete
# Original data: 9 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 200 complete
# Original data: 15 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 201 complete
# Original data: 13 empty frames
# transformation completed
# Counterclockwise rotation; 2 empty frames
# batch 202 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 2 empty frames
# batch 203 complete
# Original data: 3 empty frames
# no change necessary
# batch 204 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 205 complete
# Original data: 1 empty frames
# no change necessary
# batch 206 complete
# Original data: 4 empty frames
# no change necessary
# batch 207 complete
# Original data: 5 empty frames
# no change necessary
# batch 208 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 209 complete
# Original data: 5 empty frames
# no change necessary
# batch 210 complete
# Original data: 4 empty frames
# no change necessary
# batch 211 complete
# Original data: 5 empty frames
# no change necessary
# batch 212 complete
# Original data: 2 empty frames
# no change necessary
# batch 213 complete
# Original data: 3 empty frames
# no change necessary
# batch 214 complete
# Original data: 1 empty frames
# no change necessary
# batch 215 complete
# Original data: 1 empty frames
# no change necessary
# batch 216 complete
# Original data: 0 empty frames
# no change necessary
# batch 217 complete
# Original data: 3 empty frames
# no change necessary
# batch 218 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 6 empty frames
# too many missing frames, batch discarded
# batch 219 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 7 empty frames
# too many missing frames, batch discarded
# batch 220 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 221 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 222 complete
# Original data: 8 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 223 complete
# =======================================================
# -----------Skeleton Data Extraction Complete-----------
# =======================================================
# Array shape: (6704, 17, 2)
# Data saved to: Breast_Skel_Training.npy
# =======================================================
# CPU times: total: 57min 48s
# Wall time: 10min 32s

# %%
# %%time
video = "C:/Users/jonso/OneDrive/Desktop/Underwater Training Data.mp4"
path = 'Underwater_Skel_Training.npy'
swimPose_estimate(video, path)
#counterclockwise
# Out:
# TF: 55
# Original data: 11 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 1 complete
# Original data: 1 empty frames
# no change necessary
# batch 2 complete
# Original data: 0 empty frames
# no change necessary
# batch 3 complete
# Original data: 5 empty frames
# no change necessary
# batch 4 complete
# Original data: 0 empty frames
# no change necessary
# batch 5 complete
# Original data: 0 empty frames
# no change necessary
# batch 6 complete
# Original data: 1 empty frames
# no change necessary
# batch 7 complete
# Original data: 19 empty frames
# transformation completed
# Counterclockwise rotation; 7 empty frames
# too many missing frames, batch discarded
# batch 8 complete
# Original data: 0 empty frames
# no change necessary
# batch 9 complete
# Original data: 0 empty frames
# no change necessary
# batch 10 complete
# Original data: 0 empty frames
# no change necessary
# batch 11 complete
# Original data: 1 empty frames
# no change necessary
# batch 12 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 5 empty frames
# batch 13 complete
# Original data: 6 empty frames
# transformation completed
# Clockwise rotation; 2 empty frames
# batch 14 complete
# Original data: 3 empty frames
# no change necessary
# batch 15 complete
# Original data: 22 empty frames
# transformation completed
# Clockwise rotation; 22 empty frames
# too many missing frames, batch discarded
# batch 16 complete
# Original data: 24 empty frames
# transformation completed
# Clockwise rotation; 3 empty frames
# batch 17 complete
# Original data: 9 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 18 complete
# Original data: 8 empty frames
# transformation completed
# Clockwise rotation; 2 empty frames
# batch 19 complete
# Original data: 4 empty frames
# no change necessary
# batch 20 complete
# Original data: 15 empty frames
# transformation completed
# Clockwise rotation; 7 empty frames
# too many missing frames, batch discarded
# batch 21 complete
# Original data: 1 empty frames
# no change necessary
# batch 22 complete
# Original data: 1 empty frames
# no change necessary
# batch 23 complete
# Original data: 5 empty frames
# no change necessary
# batch 24 complete
# Original data: 11 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 25 complete
# Original data: 1 empty frames
# no change necessary
# batch 26 complete
# Original data: 4 empty frames
# no change necessary
# batch 27 complete
# Original data: 3 empty frames
# no change necessary
# batch 28 complete
# Original data: 19 empty frames
# transformation completed
# Clockwise rotation; 1 empty frames
# batch 29 complete
# Original data: 16 empty frames
# transformation completed
# Clockwise rotation; 4 empty frames
# batch 30 complete
# Original data: 10 empty frames
# transformation completed
# Clockwise rotation; 12 empty frames
# too many missing frames, batch discarded
# batch 31 complete
# Original data: 0 empty frames
# no change necessary
# batch 32 complete
# Original data: 0 empty frames
# no change necessary
# batch 33 complete
# Original data: 12 empty frames
# transformation completed
# Clockwise rotation; 17 empty frames
# too many missing frames, batch discarded
# batch 34 complete
# Original data: 7 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 35 complete
# Original data: 13 empty frames
# transformation completed
# Clockwise rotation; 0 empty frames
# batch 36 complete
# Original data: 6 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 37 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 0 empty frames
# batch 38 complete
# Original data: 16 empty frames
# transformation completed
# Counterclockwise rotation; 11 empty frames
# too many missing frames, batch discarded
# batch 39 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 1 empty frames
# batch 40 complete
# Original data: 7 empty frames
# transformation completed
# Counterclockwise rotation; 5 empty frames
# batch 41 complete
# Original data: 3 empty frames
# no change necessary
# batch 42 complete
# Original data: 0 empty frames
# no change necessary
# batch 43 complete
# Original data: 0 empty frames
# no change necessary
# batch 44 complete
# Original data: 0 empty frames
# no change necessary
# batch 45 complete
# Original data: 0 empty frames
# no change necessary
# batch 46 complete
# Original data: 0 empty frames
# no change necessary
# batch 47 complete
# Original data: 0 empty frames
# no change necessary
# batch 48 complete
# Original data: 0 empty frames
# no change necessary
# batch 49 complete
# Original data: 0 empty frames
# no change necessary
# batch 50 complete
# Original data: 0 empty frames
# no change necessary
# batch 51 complete
# Original data: 0 empty frames
# no change necessary
# batch 52 complete
# Original data: 0 empty frames
# no change necessary
# batch 53 complete
# Original data: 0 empty frames
# no change necessary
# batch 54 complete
# Original data: 0 empty frames
# no change necessary
# batch 55 complete
# =======================================================
# -----------Skeleton Data Extraction Complete-----------
# =======================================================
# Array shape: (1512, 17, 2)
# Data saved to: Underwater_Skel_Training.npy
# =======================================================
# CPU times: total: 16min 52s
# Wall time: 3min 4s

# %%
# %%time
video = "C:/Users/jonso/OneDrive/Desktop/Dive Training Data.mp4"
path = 'Dive_Skel_Training.npy'
#swimPose_estimate(video, path)
#counterclockwise
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
